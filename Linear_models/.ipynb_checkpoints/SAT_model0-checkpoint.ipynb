# %% [markdown]
# # SAT model

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('sat.txt', sep = ' ')
data.head()
# Out:
#    high_GPA  math_SAT  verb_SAT  comp_GPA  univ_GPA
# 0      3.45       643       589      3.76      3.52
# 1      2.78       558       512      2.87      2.91
# 2      2.52       583       503      2.54      2.40
# 3      3.67       685       602      3.83      3.47
# 4      3.24       592       538      3.29      3.47

# %% [markdown]
# ### Строим зависимость univ_GPA от high_GPA

# %% [markdown]
# В итоге необходимо получить что-то вроде такого:

# %%
X,Y = data[['high_GPA']], data[['univ_GPA']]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.2)

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
lr.score(X_train, y_train)
# Out:
# 0.6290427291750768

# %%
lr.score(X_test, y_test)
# Out:
# 0.5200475592642433

# %%
y_predict=lr.predict(X)

# %%
plt.plot(X, Y, 'o')
plt.plot(X, y_predict, 'k-')
plt.show()

# %%
data.columns
# Out:
# Index(['high_GPA', 'math_SAT', 'verb_SAT', 'comp_GPA', 'univ_GPA'], dtype='object')

# %%
X,Y= data[['high_GPA', 'math_SAT', 'verb_SAT', 'comp_GPA']], data[['univ_GPA']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size = 0.2)

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
lr.score(X_train, y_train)
# Out:
# 0.9036920258682358

# %%
lr.score(X_test, y_test)
# Out:
# 0.754685404428568

# %%
y_predict = lr.predict(X)

# %%
plt.plot(X, Y, 'o')
# Out:
# [<matplotlib.lines.Line2D at 0x226c0075048>,
#  <matplotlib.lines.Line2D at 0x226c0075160>,
#  <matplotlib.lines.Line2D at 0x226c00752b0>,
#  <matplotlib.lines.Line2D at 0x226c0075400>]

# %%
plt.plot(X, y_predict, 'k-')
# Out:
# [<matplotlib.lines.Line2D at 0x226c00d7c50>,
#  <matplotlib.lines.Line2D at 0x226c00d7e10>,
#  <matplotlib.lines.Line2D at 0x226c00d7f60>,
#  <matplotlib.lines.Line2D at 0x226c00e00f0>]

# %%
plt.plot(X, Y, 'o')
plt.plot(X, y_predict, 'k-')
plt.show()
